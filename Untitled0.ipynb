# %% [markdown]
# <a href="https://colab.research.google.com/github/javedmaida24-afk/API-Testing-Postman-Assignment/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# dataset load
df = sns.load_dataset("iris")

# data dekhna
print(df.shape)
print(df.columns)
print(df.head())

# summary
print(df.describe())

# scatter plot
sns.scatterplot(x="sepal_length", y="sepal_width", hue="species", data=df)
plt.show()

# histogram
df["sepal_length"].hist()
plt.show()

# box plot
sns.boxplot(x="species", y="sepal_length", data=df)
plt.show()
# Out:
# (150, 5)
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# ...
